# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiii04-25/Machine-Learning/blob/main/PCADimensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X,y=make_blobs(n_samples=500,n_features=5,centers=3,cluster_std=1.5,random_state=0)

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.8347382 , -1.79532804,  0.88822828,  0.31462876,  0.45921857],
#        [ 0.98590006,  1.16069648, -0.71841975,  0.65251573, -0.76782845],
#        [-0.84241848, -0.86544427,  1.38847193,  0.55451943,  0.63356787],
#        ...,
#        [-0.4427929 ,  1.45755686, -0.7601097 , -1.31555048,  0.97410975],
#        [-1.18846666,  1.206506  , -1.05967404, -0.65449957,  1.24079209],
#        [-0.59107866,  0.63135756, -0.40919261, -1.29870281,  0.3068221 ]])

# %%
pca=PCA(n_components=2)
X_pca=pca.fit_transform(X_scaled)

# %%
X_pca
# Out:
# array([[ 5.63525961e-01,  1.80658849e+00],
#        [ 5.20235739e-01, -1.50667414e+00],
#        [ 2.45073692e-01,  1.95649193e+00],
#        [ 1.48480942e+00, -7.51857640e-01],
#        [-2.86921882e+00,  9.61085976e-02],
#        [-2.07152225e+00,  7.75478008e-02],
#        [ 1.82233109e+00, -1.56567126e+00],
#        [ 1.38892785e+00,  1.91602628e+00],
#        [ 7.18774279e-01,  1.93572635e+00],
#        [ 9.73912860e-01, -8.43574992e-01],
#        [ 5.13561696e-01,  2.25871641e+00],
#        [ 9.80772121e-01, -1.56014429e+00],
#        [-2.50121616e+00, -1.10859223e-01],
#        [ 6.86258740e-01,  1.19693427e+00],
#        [ 5.71952696e-02,  1.85440593e+00],
#        [ 1.96543688e+00, -6.65795811e-01],
#        [ 1.19017685e+00, -9.87868751e-01],
#        [-1.46143012e+00, -2.65108933e-01],
#        [-1.83425154e+00, -3.90735943e-01],
#        [ 2.30411696e+00, -1.17243049e+00],
#        [ 1.56662404e+00, -1.42097860e+00],
#        [ 9.62555109e-01,  1.09554326e+00],
# ...

# %%
df_pca=pd.DataFrame(X_pca,columns=['PC1','PC2'])
df_pca['label']=y

# %%
sns.scatterplot(data=df_pca,x='PC1',y='PC2',hue='label')
plt.show()
