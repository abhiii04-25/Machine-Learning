# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiii04-25/Machine-Learning/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
X,y_true = make_blobs(n_samples=500, centers=3, cluster_std=0.60, random_state=42)

# %%
df=pd.DataFrame(X,columns=['Feature 1','Feature 2'])
df.head()
# Out:
#    Feature 1  Feature 2
# 0  -0.969818  -1.339938
# 1   0.963344   0.082248
# 2   1.578647   0.012635
# 3  -0.246735   1.035579
# 4   1.454170   0.049585

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
 #WCSS
inertia=[]
k_range=range(1,11)

# %%
for k in k_range:
    kmeans=KMeans(n_clusters=k,random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# %%
inertia
# Out:
# [1000.0000000000007,
#  297.8954141051722,
#  11.57548472310498,
#  9.752067977356841,
#  8.257175272446277,
#  6.917577320416794,
#  6.33475539159529,
#  5.704177177901424,
#  5.06023413353207,
#  4.762361898130391]

# %%
plt.plot(k_range,inertia,'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
kmeans_final=KMeans(n_clusters=3,random_state=42)

# %%
cluster_labels=kmeans_final.fit_predict(X_scaled)

# %%
df['cluster']=cluster_labels

# %%
sns.scatterplot(x=df['Feature 1'],
                 y=df['Feature 2'],
                 hue=df['cluster'],
                 palette='rainbow')
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
from sklearn.datasets import make_moons

# %%
X,y_true=make_moons(n_samples=500,noise=0.05,random_state=42)

# %%
from sklearn.cluster import KMeans,DBSCAN

# %%
df=pd.DataFrame(X,columns=['Feature 1','Feature 2'])
df.head()
# Out:
#    Feature 1  Feature 2
# 0   0.830586  -0.447733
# 1   0.701678   0.816918
# 2   1.022080  -0.492571
# 3  -0.316765   0.953438
# 4   0.293226   1.057185

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
kmenas=KMeans(n_clusters=2,random_state=42)
cluster_labels=kmenas.fit_predict(X_scaled)

# %%
df['kmeans_cluster']=cluster_labels

# %%
sns.scatterplot(x=df['Feature 1'],
                y=df['Feature 2'],
                hue=df['kmeans_cluster'],
                palette='rainbow')
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
dbscan=DBSCAN(eps=0.3,min_samples=5)
cluster_labels=dbscan.fit_predict(X_scaled)

# %%
df['dbscan_cluster']=cluster_labels

# %%
sns.scatterplot(x=df['Feature 1'],
                y=df['Feature 2'],
                hue=df['dbscan_cluster'],
                palette='rainbow')
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>
